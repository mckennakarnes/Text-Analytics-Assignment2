# %%
import urllib2
import pandas as pd
from bs4 import BeautifulSoup
# %config InlineBackend.figure_format = 'retina'
# %pylab inline
from IPython.core.display import display, HTML
display(HTML("<style>.container {width:100% !important;}</style>"))
# Out:
# Populating the interactive namespace from numpy and matplotlib
# <style>.container {width:100% !important;}</style>

# %%
quote_page = 'https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/p'

#Topics with more than one page of replies follows a url convention where the title is appended with /p2, /p3, and so on. 
#This loop creates a list of the first 100 replies for analysis. 
total_pages = []
for x in range(1, 200):
    q_append =quote_page+ str(x)
    total_pages.append(q_append)

# %%
df = pd.DataFrame(data=None, columns=['dates','userid','message'])
date_list = []
comment_list = []
user_list = []

for i in total_pages:
    page = urllib2.urlopen(total_pages[1])
    soup = BeautifulSoup(page, 'html.parser')

    dates = soup.findAll('time')
    datesText = [date['title'] for date in dates]
    for j in datesText:
        date_list.append(j)
    name_box = soup.find_all('div', attrs={'class': 'Message'})    
    comment = []
    [comment.append(name.text.strip()) for name in name_box]
    for j in comment:
        comment_list.append(j)
    user_box = soup.find_all('span', attrs={'class': 'Author'})
    userid =  []
    [userid.append(title.text.strip()) for title in user_box]
    for j in userid:
        user_list.append(j)

# %%
date_list = []
comment_list = []
user_list = []

for i in total_pages:
    page = urllib2.urlopen(total_pages[1])
    soup = BeautifulSoup(page, 'html.parser')

    dates = soup.findAll('time')
    datesText = [date['title'] for date in dates]
    
    name_box = soup.find_all('div', attrs={'class': 'Message'})    
    comment = []
    [comment.append(name.text.strip()) for name in name_box]
    
    user_box = soup.find_all('span', attrs={'class': 'Author'})
    userid =  []
    [userid.append(title.text.strip()) for title in user_box]
    for j in range(0,len(datesText)-1):
        comment_list.append(comment[j])
        date_list.append(datesText[j])
        user_list.append(userid[j])

# %%
df=pd.DataFrame(date_list,columns=['date'])
df2= pd.DataFrame(user_list, columns=['userid'])
df3=pd.DataFrame(comment_list, columns=['message'])
new_df = pd.merge(df, df2, right_index=True, left_index=True)
final_df = pd.merge(new_df, df3, right_index=True, left_index=True)
final_df
# Out:
#                         date         userid  \
# 0     April 12, 2002  2:53PM          merc1
# 1     April 14, 2002  8:09AM         popovs
# 2     April 17, 2002  9:23AM         popovs
# 3     April 17, 2002  7:37PM        mvargo1
# 4     April 17, 2002  8:11PM     wishnhigh1
# 5     April 18, 2002 11:12PM       cybersol
# 6     April 18, 2002 11:50PM           riez
# 7     April 19, 2002  1:07AM       cybersol
# 8     April 19, 2002  2:14AM      kdshapiro
# 9     April 19, 2002  2:18AM           riez
# 10    April 19, 2002  3:28PM       dave330i
# 11    April 20, 2002  8:18AM       cybersol
# 12    April 20, 2002  4:49PM           riez
# 13    April 21, 2002  7:36AM       cybersol
# 14    April 21, 2002  1:50PM           riez
# 15    April 24, 2002  2:51PM     beartrax79
# 11    Riez, you have heard of speed sensitive steeri...
# 12    cybersol...  There are two types.  Those tied ...
# 13    Yeah, I have that brouchure and they don't men...
# 14    cybersol...  From what I've read, the better v...
# 15    So, if you read through most of this group, al...
# 16    Have you driven them both?  The S4 really move...
# 17    I've tested the 3.0, not the S4.  Hmmm... new ...
# 18    Yeah, the current S4 has 250 hp and 258 lb-ft ...
# 19    Not so fast.  There is merit to the "nationali...
# 20    The problem is that they are HUGE generalizati...
# 21    Have found out that with some of the more powe...
# 22    How does your theory explain English cars? A c...
# 23    "Being that it is an automatic I can enjoy my ...
# 24    He did mention "in rush hour traffic."  Like t...
# 25    Edmunds has a new feature called "True Cost To...
# 26    I have not had a chance to look at it in perso...
# 27    But it's not really a performance sedan.  Driv...
# 28    I beg to differ.While I admit that I am biased...
# 29    I recently went through the list of entry leve...
# ...                                                 ...
# 5940  Well I'm a Benz fan first and foremost, but th...
# 5941  I think both are excellent(sp?) cars, however ...
# 5942  It has come to my attention that as of late MB...
# 5943  There is not much to debate on this subject.  ...
# 5944  gave up nationality based generalizations a co...
# 5945  I'm interested more towards performance than l...
# 5946  cybersol...  I can't fathom why you would want...
# 5947  Sorry to disappoint with the slushbox, but if ...
# 5948  The new Altima is great as my friends just bou...
# 5949  cybersol... Excitement and slushbox don't seem...
# 5950  "Excitement and slushbox don't seem to be comp...
# 5951  Riez, you have heard of speed sensitive steeri...
# 5952  cybersol...  There are two types.  Those tied ...
# 5953  Yeah, I have that brouchure and they don't men...
# 5954  cybersol...  From what I've read, the better v...
# 5955  So, if you read through most of this group, al...
# 5956  Have you driven them both?  The S4 really move...
# 5957  I've tested the 3.0, not the S4.  Hmmm... new ...
# 5958  Yeah, the current S4 has 250 hp and 258 lb-ft ...
# 5959  Not so fast.  There is merit to the "nationali...
# 5960  The problem is that they are HUGE generalizati...
# 5961  Have found out that with some of the more powe...
# 5962  How does your theory explain English cars? A c...
# 5963  "Being that it is an automatic I can enjoy my ...
# 5964  He did mention "in rush hour traffic."  Like t...
# 5965  Edmunds has a new feature called "True Cost To...
# 5966  I have not had a chance to look at it in perso...
# 5967  But it's not really a performance sedan.  Driv...
# 5968  I beg to differ.While I admit that I am biased...
# 5969  I recently went through the list of entry leve...
#
# [5970 rows x 3 columns]

# %%
final_df.to_csv('out.csv', sep=',')

# %%
name_box = soup.find_all('div', attrs={'class': 'Message'})    
comment = []
[comment.append(name.text.strip()) for name in name_box]
len(comment)
# Out:
# 30

# %%
raw_data = {'date': time, 'userid': userid, 'message': comment}
df = pd.DataFrame(raw_data, columns = ['date', 'userid', 'message'])
# df.to_csv('EdmundsCarScrapper.csv')
