# %% [markdown]
# # Text Analytics Group Assignment2
# Due: September 25, 2017, by 11:59 p.m. In this assignment you are an analytics consultant to a   (i) brand manager, (ii) product manager and (iii)advertising manager. Your job is    to give advice/insights to these individuals based on the analysis of social media conversations. The detailed tasks are described below. We use cars as an example of a “high involvement” good (recall from class discussions that for high involvement goods, people use social media heavily for awareness building and research).
#
# 1.Develop a   crawler/scraper to fetch messages posted in Edmunds.com discussion forums. The crawler output should be a .csv file with the following columns: date, userid, and message (even though you will only use the messages in your analysis). Before you develop the crawler, carefully study one of the forums on Edmunds.com to understand the html as well as the threading structures.
#
# 2.Fetch between 5,000 and 10,000 posts about cars from a General topics forum. Do NOT choosea forum dedicated to a   particular brand or model. Instead, you can choose the General & Sedans categories and then select, for example, the Entry Level Luxury forum https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedansThe idea is    to have multiple brands and models being discussed without one of them being the focal point.
#
# 3.Once you fetch the data, find the top 10 brands from frequency counts. You will need to write a script to count the frequencies. Be sure not to count a mention more than once per post, evenif   it    is mentioned multiple times.Replace modelswith brands so that from now on you have to deal with only brands and not models. You will need another script for this job. This step is meant to help simplify the analysis. A    list of model and brand names (not exhaustive) are provided in a separate file.

# %% [markdown]
# #### Task A:
# Identify top 10 brands by frequency. From the posts, calculate lift ratios for associations between the brands. You will have to write a   script to do this task). Show the brands on a   multi-dimensional scaling (MDS) map (use a Python script for MDS, there are multiple scripts available onthe Internet).

# %%
#car forum data
forum_data =pd.read_csv('cars_data.csv', header = 0)
forum_data = forum_data[['date','userid','message']]

df2=pd.DataFrame([['April 12, 2002 2:53PM','dani','audi bmw acura nissan volkswagen honda toyota chrysler mercedes subaru']], columns=['date','userid','message'])
forum_data=forum_data.append(df2)
forum_data['message']=forum_data['message'].str.lower()
forum_data
# Out:
#                         date         userid  \
# 0     April 12, 2002  2:53PM          merc1
# 1     April 14, 2002  8:09AM         popovs
# 2     April 17, 2002  9:23AM         popovs
# 3     April 17, 2002  7:37PM        mvargo1
# 4     April 17, 2002  8:11PM     wishnhigh1
# 5     April 18, 2002 11:12PM       cybersol
# 6     April 18, 2002 11:50PM           riez
# 7     April 19, 2002  1:07AM       cybersol
# 8     April 19, 2002  2:14AM      kdshapiro
# 9     April 19, 2002  2:18AM           riez
# 10    April 19, 2002  3:28PM       dave330i
# 11    April 20, 2002  8:18AM       cybersol
# 12    April 20, 2002  4:49PM           riez
# 13    April 21, 2002  7:36AM       cybersol
# 14    April 21, 2002  1:50PM           riez
# 15    April 24, 2002  2:51PM     beartrax79
# 16    April 25, 2002 12:15AM       cybersol
# 17    April 25, 2002  7:36PM     beartrax79
# 18    April 26, 2002  4:50PM       cybersol
# 19    April 27, 2002  9:37PM        1pierce
# 20    April 27, 2002  9:54PM     wishnhigh1
# 21    April 28, 2002  2:38AM         kd6aw1
# 22    April 28, 2002 10:11AM        fwatson
# 23    April 29, 2002  2:59PM       dave330i
# 24    April 29, 2002  5:12PM  blueguydotcom
# 25      May  3, 2002  2:11PM         fredvh
# 26      May 23, 2002  5:02PM       cybersol
# 27      May 23, 2002  5:18PM  blueguydotcom
# 28      May 28, 2002  2:50PM       rayainsw
# 29    April 12, 2002  2:53PM          merc1
# ...                      ...            ...
# 5742  April 12, 2002  2:53PM          merc1
# 5743  April 14, 2002  8:09AM         popovs
# 5744  April 17, 2002  9:23AM         popovs
# 5745  April 17, 2002  7:37PM        mvargo1
# 5746  April 17, 2002  8:11PM     wishnhigh1
# 5747  April 18, 2002 11:12PM       cybersol
# 5748  April 18, 2002 11:50PM           riez
# 5749  April 19, 2002  1:07AM       cybersol
# 5750  April 19, 2002  2:14AM      kdshapiro
# 5751  April 19, 2002  2:18AM           riez
# 5752  April 19, 2002  3:28PM       dave330i
# 5753  April 20, 2002  8:18AM       cybersol
# 5754  April 20, 2002  4:49PM           riez
# 5755  April 21, 2002  7:36AM       cybersol
# 5756  April 21, 2002  1:50PM           riez
# 5757  April 24, 2002  2:51PM     beartrax79
# 5758  April 25, 2002 12:15AM       cybersol
# 5759  April 25, 2002  7:36PM     beartrax79
# 5760  April 26, 2002  4:50PM       cybersol
# 5761  April 27, 2002  9:37PM        1pierce
# 5762  April 27, 2002  9:54PM     wishnhigh1
# 5763  April 28, 2002  2:38AM         kd6aw1
# 5764  April 28, 2002 10:11AM        fwatson
# 5765  April 29, 2002  2:59PM       dave330i
# 5766  April 29, 2002  5:12PM  blueguydotcom
# 5767    May  3, 2002  2:11PM         fredvh
# 5768    May 23, 2002  5:02PM       cybersol
# 5769    May 23, 2002  5:18PM  blueguydotcom
# 5770    May 28, 2002  2:50PM       rayainsw
# 0      April 12, 2002 2:53PM           dani
#
#                                                 message
# 0     well i'm a benz fan first and foremost, but th...
# 1     i think both are excellent(sp?) cars, however ...
# 2     it has come to my attention that as of late mb...
# 3     there is not much to debate on this subject.  ...
# 4     gave up nationality based generalizations a co...
# 5     i'm interested more towards performance than l...
# 6     cybersol...  i can't fathom why you would want...
# 7     sorry to disappoint with the slushbox, but if ...
# 8     the new altima is great as my friends just bou...
# 9     cybersol... excitement and slushbox don't seem...
# 10    "excitement and slushbox don't seem to be comp...
# 11    riez, you have heard of speed sensitive steeri...
# 12    cybersol...  there are two types.  those tied ...
# 13    yeah, i have that brouchure and they don't men...
# 14    cybersol...  from what i've read, the better v...
# 15    so, if you read through most of this group, al...
# 16    have you driven them both?  the s4 really move...
# 17    i've tested the 3.0, not the s4.  hmmm... new ...
# 18    yeah, the current s4 has 250 hp and 258 lb-ft ...
# 19    not so fast.  there is merit to the "nationali...
# 20    the problem is that they are huge generalizati...
# 21    have found out that with some of the more powe...
# 22    how does your theory explain english cars? a c...
# 23    "being that it is an automatic i can enjoy my ...
# 24    he did mention "in rush hour traffic."  like t...
# 25    edmunds has a new feature called "true cost to...
# 26    i have not had a chance to look at it in perso...
# 27    but it's not really a performance sedan.  driv...
# 28    i beg to differ.while i admit that i am biased...
# 29    well i'm a benz fan first and foremost, but th...
# ...                                                 ...
# 5742  well i'm a benz fan first and foremost, but th...
# 5743  i think both are excellent(sp?) cars, however ...
# 5744  it has come to my attention that as of late mb...
# 5745  there is not much to debate on this subject.  ...
# 5746  gave up nationality based generalizations a co...
# 5747  i'm interested more towards performance than l...
# 5748  cybersol...  i can't fathom why you would want...
# 5749  sorry to disappoint with the slushbox, but if ...
# 5750  the new altima is great as my friends just bou...
# 5751  cybersol... excitement and slushbox don't seem...
# 5752  "excitement and slushbox don't seem to be comp...
# 5753  riez, you have heard of speed sensitive steeri...
# 5754  cybersol...  there are two types.  those tied ...
# 5755  yeah, i have that brouchure and they don't men...
# 5756  cybersol...  from what i've read, the better v...
# 5757  so, if you read through most of this group, al...
# 5758  have you driven them both?  the s4 really move...
# 5759  i've tested the 3.0, not the s4.  hmmm... new ...
# 5760  yeah, the current s4 has 250 hp and 258 lb-ft ...
# 5761  not so fast.  there is merit to the "nationali...
# 5762  the problem is that they are huge generalizati...
# 5763  have found out that with some of the more powe...
# 5764  how does your theory explain english cars? a c...
# 5765  "being that it is an automatic i can enjoy my ...
# 5766  he did mention "in rush hour traffic."  like t...
# 5767  edmunds has a new feature called "true cost to...
# 5768  i have not had a chance to look at it in perso...
# 5769  but it's not really a performance sedan.  driv...
# 5770  i beg to differ.while i admit that i am biased...
# 0     audi bmw acura nissan volkswagen honda toyota ...
#
# [5772 rows x 3 columns]

# %%
#list of car brands/names
model_list =pd.read_csv('Cars make model list3.csv', header = 2)

model_list['Search']=model_list['Search'].str.lower()
model_list
# Out:
#         Replace      Search
# 0         acura     integra
# 1         acura     legend�
# 2         acura       vigor
# 3         acura         rlx
# 4         acura         ilx
# 5         acura         mdx
# 6         acura         rdx
# 7         acura         tsx
# 8         acura         rsx
# 9          audi     quattro
# 10         audi          a4
# 11         audi          a6
# 12         audi          a5
# 13         audi          a7
# 14         audi          q3
# 15         audi          q5
# 16         audi          q7
# 17         audi          a8
# 18         audi          a3
# 19          bmw    3-series
# 20          bmw    5-series
# 21          bmw    6-series
# 22          bmw    4-series
# 23          bmw      xdrive
# 24          bmw      alpina
# 25          bmw       330ci
# 26          bmw        328i
# 27          bmw        330c
# 28          bmw        335i
# 29          bmw        335d
# ..          ...         ...
# 491      toyota       prius
# 492      toyota       venza
# 493      toyota      camrys
# 494      toyota      avalon
# 495      toyota      solara
# 496      toyota     corolla
# 497      toyota     toyotas
# 498      toyota  highlander
# 499  volkswagen  sportwagen
# 500  volkswagen     touraeg
# 501  volkswagen      passat
# 502  volkswagen      tiguan
# 503  volkswagen      beetle
# 504  volkswagen      rabbit
# 505  volkswagen       jetta
# 506  volkswagen        golf
# 507  volkswagen         gti
# 508  volkswagen         eos
# 509  volkswagen   volkwagen
# 510  volkswagen          vw
# 511  volkswagen         vws
# 512  volkswagen     passats
# 513  volkswagen      passat
# 514       volvo        xc60
# 515       volvo        xc70
# 516       volvo        xc90
# 517       volvo         s60
# 518       volvo         s80
# 519       volvo         v60
# 520       volvo         c70
#
# [521 rows x 2 columns]

# %%
##some of the Search values from the model_list df have a weird format after that we need to remove
#'legend\xca'.replace('\xc2\xa0','')
model_list['Search'].replace('\xca','').values

ls=model_list['Search'].tolist()
for i in range(len(ls)):
    ls[i]=ls[i].replace('\xca','')
range(len(ls))
ls #the correct names now! add this back to model_list df
model_list['Search1']=ls #setting new column equal to correct values
model_list['Search1'].values
# Out:
# array(['integra', 'legend', 'vigor', 'rlx', 'ilx', 'mdx', 'rdx', 'tsx',
#        'rsx', 'quattro', 'a4', 'a6', 'a5', 'a7', 'q3', 'q5', 'q7', 'a8',
#        'a3', '3-series', '5-series', '6-series', '4-series', 'xdrive',
#        'alpina', '330ci', '328i', '330c', '335i', '335d', '528i', '535i',
#        '128i', '640i', '3er', '5er', 'm5', 'm3', 'm6', 'bmws', 'bmwesque',
#        'park avenue', 'la crosse', 'lacrosse', 'century', 'enclave',
#        'encore', 'regal', 'buicks', 'escalade', 'srx', 'xts',
#        'grand blazer', 'trailblazer', 'trailblazer', 'silverado',
#        'colorado', 'corvette', 'suburban', 'cavalier', 'caprice',
#        'captiva', 'equinox', 'express', 'lacetti', 'montana', 'uplander',
#        'orlando', 'tornado', 'tracker', 'traverse', 'caprice', 'captiva',
#        'equinox', 'express', 'camaro', 'cobalt', 'impala', 'lumina',
#        'malibu', 'prisma', 'tavera', 'camaro', 'cobalt', 'impala',
#        'lumina', 'malibu', 'tavera', 'agile', 'celta', 'cruze', 'lanos',
#        'omega', 'optra', 'sonic', 'spark', 'tahoe', 'agile', 'cruze',
#        'sonic', 'spark', 'aveo', 'lova', 'n200', 'niva', 'onix', 's-10',
#        'sail', 'volt', 'aveo', 'volt', 'chevy', 'malibus', 'suburban',
#        'corvette', 'town and country', 'chrysler 300', 'chrysler 200',
#        'pacifica', 'cruiser', 'sebring', '300m', 'lx', 'chryslers',
#        'challenger', 'intrepid', 'avenger', 'charger', 'durango',
#        'journey', 'caliber', 'stealth', 'magnum', 'viper', 'dart', 'ram',
#        'crownvictoria', 'expedition', 'supervan', 'freestar', 'explorer',
#        'mustang', 'ecoline', 'tourneo', 'everest', 'fiesta', 'fusion',
#        'taurus', 'galaxy', 'escape', 'focus', 'f-150', 'c-max', 's-max',
#        'kuga', 'cmax', 'f150', 'fords', 'fusions', 'fusionmilan',
#        'crosstour', 'ridgeline', 'inspire', 'mobilio', 'prelude',
#        'shuttle', 'spirior', 'stepwgn', 'crider', 'insight', 'legend',
#        'odyssey', 'stream', 'amaze', 'hobio', 'n-box', 'n-one', 'n-wgn',
#        'pilot', 'vamos', 'vezel', 'spike', 'acty', 'brio', 'city', 'civic',
#        'cr-v', 'freed', 'jade', 'zest', 'aria', 'ex-l', 'cr-z', 'jazz',
#        'nsx', 'nbox', 'exl', 'fcx', '5dr', 'crv', 'pilot', 'accord',
#        'hondas', 'accords', 'odessey', 'crosstour', 'centennial',
#        'grandeur', 'veloster', 'elantra', 'genesis', 'tiburon', 'tuscani',
#        'dynasty', 'santamo', 'stellar', 'accent', 'lantra', 'avante',
#        'santro', 'sonata', 'scoupe', 'matrix', 'lavity', 'verna', 'equus',
#        'azera', 'xcent', 'click', 'atos', 'atoz', 'ix20', 'getz', 'pony',
#        'i10', 'i20', 'i30', 'i40', 'i45', 'xg', 'santa', 'sonatas',
#        'hyundais', 'veracruz', 'excel', 'qx50', 'qx60', 'qx70', 'fx35',
#        'q50', 'q60', 'q70', 'g37', 'g25', '6mt', 'cadenza', 'sorento',
#        'sedona', 'forte', 'koup', 'k900', 'kias', 'optima', 'navigator',
#        'town car', 'zephyr', 'mkz', 'mks', 'mkx', 'mkc', 'mkt',
#        'az-offroad', 'az-wagon', 'familia', 'premacy', 'biante', 'carol',
#        'scrum', 'mazda2', 'mazda3', 'mazda5', 'atenza', 'mazda6', 'mazda8',
#        'bongo', 'demio', 'axela', 'rx-8', 'cx-7', 'bt-50', 'rx-8', 'mx-5',
#        'cx-5', 'cx-9', '6i', 'cx9', 'cx5', 'rx8', 'mazdas', 'mazda6s',
#        'mazda6i', 'mercedes-benz', 'benz', 'cl-class', 'c-class',
#        'e-class', 's-class', 'mercedesbenz', 'mercedes', 'mercedes',
#        'milan', 'mercury', 'galant', 'lancer', 'pathfinder', 'frontier',
#        'sentra', 'altima', 'maxima', 'murano', 'armada', 'xterra', 'versa',
#        'rogue', 'titan', 'cube', 'juke', 'leaf', '370z', 'altimas',
#        'nissans', 'quest', 'streamliner', 'grand prix', 'grand am',
#        'sunfire', 'torpedo', 'aztek', 'vibe', 'wave', 'vibe', 'gxp', 'gto',
#        'g6', 'g3', 'g4', 'g5', 'g6', 'g8', 'aura', 'outback sport',
#        'grand wagon', 'impreza xv', 'crosstrek', 'lancaster', 'forester',
#        'impreza', 'tribeca', 'liberty', 'outback', 'gravel', 'legacy',
#        'sambar', 'stella', 'exiga', 'pleo', 'brz', 'wrx', 'dex', 'r1',
#        'r2', 'every landy', 'cappuccino', 'mighty boy', 'geo metro',
#        'mr wagon', 'palette', 'wagon r', 'kizashi', 'equator', 'splash',
#        'ertiga', 'cultus', 'esteem', 'fronte', 'escudo', 'lapin', 'solio',
#        'swift', 'landy', 'jimny', 'aerio', 'liana', 'cervo', 'forsa',
#        'ignis', 'x-90', 'xl7', 'sx4', 'apv', 'camrybest',
#        'corolla/sprinter', 'urban cruiser', 'land cruiser', 'highlander',
#        'fj cruiser', 'hilux surf', 'fortuner', 'stallion', 'vanguard',
#        '4runner', 'alphard', 'avensis', 'century', 'coaster', 'comfort',
#        'granvia', 'liteace', 'scepter', 'sequoia', 'succeed', 'townace',
#        'toyoace', 'venture', 'allion', 'aurion', 'avalon', 'avanza',
#        'condor', 'fiedler', 'majesta', 'estima', 'hiclass', 'innova',
#        'kijang', 'kingdom', 'kluger', 'matrix', 'miniace', 'picnic',
#        'premio', 'probox', 'qualis', 'ractis', 'sienna', 'sienta',
#        'sparky', 'tacoma', 'tamaraw', 'tarago', 'tundra', 'vienta',
#        'auris', 'belta', 'camry', 'carri', 'rumion', 'etios', 'hilux',
#        'hiace', 'mark x', 'passo', 'porte', 'prius', 'sofia', 'tiara',
#        'venza', 'verso', 'yaris', 'zelas', 'aygo', 'cami', 'dyna', 'isis',
#        'nadia', 'noah', 'raum', 'rav4', 'reiz', 'vios', 'voxy', 'platz',
#        'axio', 'ist', 'sai', 'vitz', 'echo', 'bb', 'iq', 'zio', 'camry',
#        'prius', 'venza', 'camrys', 'avalon', 'solara', 'corolla',
#        'toyotas', 'highlander', 'sportwagen', 'touraeg', 'passat',
#        'tiguan', 'beetle', 'rabbit', 'jetta', 'golf', 'gti', 'eos',
#        'volkwagen', 'vw', 'vws', 'passats', 'passat', 'xc60', 'xc70',
#        'xc90', 's60', 's80', 'v60', 'c70'], dtype=object)

# %%
#formula to replace model names with brand names
#split each message into words. if word in search values, replace with matching idx number?
import numpy as np
def replace_model(s):
    mess=s.split()
    mess_rep=[]
    for word in mess:
        if word in model_list['Search1'].values:
            mask=(model_list['Search1']==word)
            word=model_list[mask]['Replace'].values[0]
            mess_rep.append(word)
        else:
            mess_rep.append(word)
    new_mess=' '.join(mess_rep)        
    return new_mess
    
            
replace_model('I love my legend') #YAY
replace_model('I love my quattro')
# Out:
# 'I love my audi'

# %%
#mapping that function to forum df
forum_data['message_clean']=forum_data['message'].map(replace_model)

# %%
from nltk.corpus import stopwords
stop = stopwords.words('english')
# final_df.message.apply(lambda x: [item for item in x if item not in stop])
forum_data['message_without_stopwords'] = forum_data['message_clean'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop)]))

# %%
forum_data
# Out:
#                         date         userid  \
# 0     April 12, 2002  2:53PM          merc1
# 1     April 14, 2002  8:09AM         popovs
# 2     April 17, 2002  9:23AM         popovs
# 3     April 17, 2002  7:37PM        mvargo1
# 4     April 17, 2002  8:11PM     wishnhigh1
# 5     April 18, 2002 11:12PM       cybersol
# 6     April 18, 2002 11:50PM           riez
# 7     April 19, 2002  1:07AM       cybersol
# 8     April 19, 2002  2:14AM      kdshapiro
# 9     April 19, 2002  2:18AM           riez
# 10    April 19, 2002  3:28PM       dave330i
# 11    April 20, 2002  8:18AM       cybersol
# 12    April 20, 2002  4:49PM           riez
# 13    April 21, 2002  7:36AM       cybersol
# 14    April 21, 2002  1:50PM           riez
# 15    April 24, 2002  2:51PM     beartrax79
# 16    April 25, 2002 12:15AM       cybersol
# 17    April 25, 2002  7:36PM     beartrax79
# 18    April 26, 2002  4:50PM       cybersol
# 19    April 27, 2002  9:37PM        1pierce
# 20    April 27, 2002  9:54PM     wishnhigh1
# 21    April 28, 2002  2:38AM         kd6aw1
# 22    April 28, 2002 10:11AM        fwatson
# 23    April 29, 2002  2:59PM       dave330i
# 24    April 29, 2002  5:12PM  blueguydotcom
# 25      May  3, 2002  2:11PM         fredvh
# 26      May 23, 2002  5:02PM       cybersol
# 27      May 23, 2002  5:18PM  blueguydotcom
# 28      May 28, 2002  2:50PM       rayainsw
# 29    April 12, 2002  2:53PM          merc1
# ...                      ...            ...
# 5742  April 12, 2002  2:53PM          merc1
# 5743  April 14, 2002  8:09AM         popovs
# 5744  April 17, 2002  9:23AM         popovs
# 5745  April 17, 2002  7:37PM        mvargo1
# 5746  April 17, 2002  8:11PM     wishnhigh1
# 5747  April 18, 2002 11:12PM       cybersol
# 5748  April 18, 2002 11:50PM           riez
# 5749  April 19, 2002  1:07AM       cybersol
# 5750  April 19, 2002  2:14AM      kdshapiro
# 5751  April 19, 2002  2:18AM           riez
# 5752  April 19, 2002  3:28PM       dave330i
# 5753  April 20, 2002  8:18AM       cybersol
# 5754  April 20, 2002  4:49PM           riez
# 5755  April 21, 2002  7:36AM       cybersol
# 5756  April 21, 2002  1:50PM           riez
# 5757  April 24, 2002  2:51PM     beartrax79
# 5758  April 25, 2002 12:15AM       cybersol
# 5759  April 25, 2002  7:36PM     beartrax79
# 5760  April 26, 2002  4:50PM       cybersol
# 5761  April 27, 2002  9:37PM        1pierce
# 5762  April 27, 2002  9:54PM     wishnhigh1
# 5763  April 28, 2002  2:38AM         kd6aw1
# 5764  April 28, 2002 10:11AM        fwatson
# 5765  April 29, 2002  2:59PM       dave330i
# 5766  April 29, 2002  5:12PM  blueguydotcom
# 5767    May  3, 2002  2:11PM         fredvh
# 5768    May 23, 2002  5:02PM       cybersol
# 5769    May 23, 2002  5:18PM  blueguydotcom
# 5770    May 28, 2002  2:50PM       rayainsw
# 0      April 12, 2002 2:53PM           dani
#
#                                                 message  \
# 0     well i'm a benz fan first and foremost, but th...
# 1     i think both are excellent(sp?) cars, however ...
# 2     it has come to my attention that as of late mb...
# 3     there is not much to debate on this subject.  ...
# 4     gave up nationality based generalizations a co...
# 5     i'm interested more towards performance than l...
# 6     cybersol...  i can't fathom why you would want...
# 7     sorry to disappoint with the slushbox, but if ...
# 8     the new altima is great as my friends just bou...
# 9     cybersol... excitement and slushbox don't seem...
# 10    "excitement and slushbox don't seem to be comp...
# 11    riez, you have heard of speed sensitive steeri...
# 12    cybersol...  there are two types.  those tied ...
# 13    yeah, i have that brouchure and they don't men...
# 14    cybersol...  from what i've read, the better v...
# 15    so, if you read through most of this group, al...
# 16    have you driven them both?  the s4 really move...
# 17    i've tested the 3.0, not the s4.  hmmm... new ...
# 18    yeah, the current s4 has 250 hp and 258 lb-ft ...
# 19    not so fast.  there is merit to the "nationali...
# 20    the problem is that they are huge generalizati...
# 21    have found out that with some of the more powe...
# 22    how does your theory explain english cars? a c...
# 23    "being that it is an automatic i can enjoy my ...
# 24    he did mention "in rush hour traffic."  like t...
# 25    edmunds has a new feature called "true cost to...
# 26    i have not had a chance to look at it in perso...
# 27    but it's not really a performance sedan.  driv...
# 28    i beg to differ.while i admit that i am biased...
# 29    well i'm a benz fan first and foremost, but th...
# ...                                                 ...
# 5742  well i'm a benz fan first and foremost, but th...
# 5743  i think both are excellent(sp?) cars, however ...
# 5744  it has come to my attention that as of late mb...
# 5745  there is not much to debate on this subject.  ...
# 5746  gave up nationality based generalizations a co...
# 5747  i'm interested more towards performance than l...
# 5748  cybersol...  i can't fathom why you would want...
# 5749  sorry to disappoint with the slushbox, but if ...
# 5750  the new altima is great as my friends just bou...
# 5751  cybersol... excitement and slushbox don't seem...
# 5752  "excitement and slushbox don't seem to be comp...
# 5753  riez, you have heard of speed sensitive steeri...
# 5754  cybersol...  there are two types.  those tied ...
# 5755  yeah, i have that brouchure and they don't men...
# 5756  cybersol...  from what i've read, the better v...
# 5757  so, if you read through most of this group, al...
# 5758  have you driven them both?  the s4 really move...
# 5759  i've tested the 3.0, not the s4.  hmmm... new ...
# 5760  yeah, the current s4 has 250 hp and 258 lb-ft ...
# 5761  not so fast.  there is merit to the "nationali...
# 5762  the problem is that they are huge generalizati...
# 5763  have found out that with some of the more powe...
# 5764  how does your theory explain english cars? a c...
# 5765  "being that it is an automatic i can enjoy my ...
# 5766  he did mention "in rush hour traffic."  like t...
# 5767  edmunds has a new feature called "true cost to...
# 5768  i have not had a chance to look at it in perso...
# 5769  but it's not really a performance sedan.  driv...
# 5770  i beg to differ.while i admit that i am biased...
# 0     audi bmw acura nissan volkswagen honda toyota ...
#
#                                           message_clean  \
# 0     well i'm a mercedes fan first and foremost, bu...
# 1     i think both are excellent(sp?) cars, however ...
# 2     it has come to my attention that as of late mb...
# 3     there is not much to debate on this subject. i...
# 4     gave up nationality based generalizations a co...
# 5     i'm interested more towards performance than l...
# 6     cybersol... i can't fathom why you would want ...
# 7     sorry to disappoint with the slushbox, but if ...
# 8     the new nissan is great as my friends just bou...
# 9     cybersol... excitement and slushbox don't seem...
# 10    "excitement and slushbox don't seem to be comp...
# 11    riez, you have heard of speed sensitive steeri...
# 12    cybersol... there are two types. those tied to...
# 13    yeah, i have that brouchure and they don't men...
# 14    cybersol... from what i've read, the better va...
# 15    so, if you read through most of this group, al...
# 16    have you driven them both? the s4 really moves...
# 17    i've tested the 3.0, not the s4. hmmm... new s...
# 18    yeah, the current s4 has 250 hp and 258 lb-ft ...
# 19    not so fast. there is merit to the "nationalit...
# 20    the problem is that they are huge generalizati...
# 21    have found out that with some of the more powe...
# 22    how does your theory explain english cars? a c...
# 23    "being that it is an automatic i can enjoy my ...
# 24    he did mention "in rush hour traffic." like th...
# 25    edmunds has a new feature called "true cost to...
# 26    i have not had a chance to look at it in perso...
# 27    but it's not really a performance sedan. drive...
# 28    i beg to differ.while i admit that i am biased...
# 29    well i'm a mercedes fan first and foremost, bu...
# ...                                                 ...
# 5742  well i'm a mercedes fan first and foremost, bu...
# 5743  i think both are excellent(sp?) cars, however ...
# 5744  it has come to my attention that as of late mb...
# 5745  there is not much to debate on this subject. i...
# 5746  gave up nationality based generalizations a co...
# 5747  i'm interested more towards performance than l...
# 5748  cybersol... i can't fathom why you would want ...
# 5749  sorry to disappoint with the slushbox, but if ...
# 5750  the new nissan is great as my friends just bou...
# 5751  cybersol... excitement and slushbox don't seem...
# 5752  "excitement and slushbox don't seem to be comp...
# 5753  riez, you have heard of speed sensitive steeri...
# 5754  cybersol... there are two types. those tied to...
# 5755  yeah, i have that brouchure and they don't men...
# 5756  cybersol... from what i've read, the better va...
# 5757  so, if you read through most of this group, al...
# 5758  have you driven them both? the s4 really moves...
# 5759  i've tested the 3.0, not the s4. hmmm... new s...
# 5760  yeah, the current s4 has 250 hp and 258 lb-ft ...
# 5761  not so fast. there is merit to the "nationalit...
# 5762  the problem is that they are huge generalizati...
# 5763  have found out that with some of the more powe...
# 5764  how does your theory explain english cars? a c...
# 5765  "being that it is an automatic i can enjoy my ...
# 5766  he did mention "in rush hour traffic." like th...
# 5767  edmunds has a new feature called "true cost to...
# 5768  i have not had a chance to look at it in perso...
# 5769  but it's not really a performance sedan. drive...
# 5770  i beg to differ.while i admit that i am biased...
# 0     audi bmw acura nissan volkswagen honda toyota ...
#
#                               message_without_stopwords
# 0     well i'm mercedes fan first foremost, audi 3.0...
# 1     think excellent(sp?) cars, however neither one...
# 2     come attention late mb taken hit reputation. p...
# 3     much debate subject. want reliable car buy jap...
# 4     gave nationality based generalizations couple ...
# 5     i'm interested towards performance luxury. als...
# 6     cybersol... can't fathom would want go slushbo...
# 7     sorry disappoint slushbox, life would boring (...
# 8     new nissan great friends bought one. however, ...
# 9     cybersol... excitement slushbox don't seem com...
# 10    "excitement slushbox don't seem compatible."ag...
# 11    riez, heard speed sensitive steering? varies p...
# 12    cybersol... two types. tied engine output tied...
# 13    yeah, brouchure don't mention difference tl tl...
# 14    cybersol... i've read, better variable power a...
# 15    so, read group, alot references went audi... g...
# 16    driven both? s4 really moves. even audi's 0-60...
# 17    i've tested 3.0, s4. hmmm... new s4 '03, huh? ...
# 18    yeah, current s4 250 hp 258 lb-ft torque. torq...
# 19    fast. merit "nationality based" debate. let ex...
# 20    problem huge generalizations. also, talking ja...
# 21    found powerful cars like g35 chevrolet differe...
# 22    theory explain english cars? country steeped t...
# 23    "being automatic enjoy coffee, shave, talk cel...
# 24    mention "in rush hour traffic." like there's a...
# 25    edmunds new feature called "true cost own". li...
# 26    chance look person, 38k volkswagen w8 fit entr...
# 27    it's really performance sedan. drive one take ...
# 28    beg differ.while admit biased (obviously, sinc...
# 29    well i'm mercedes fan first foremost, audi 3.0...
# ...                                                 ...
# 5742  well i'm mercedes fan first foremost, audi 3.0...
# 5743  think excellent(sp?) cars, however neither one...
# 5744  come attention late mb taken hit reputation. p...
# 5745  much debate subject. want reliable car buy jap...
# 5746  gave nationality based generalizations couple ...
# 5747  i'm interested towards performance luxury. als...
# 5748  cybersol... can't fathom would want go slushbo...
# 5749  sorry disappoint slushbox, life would boring (...
# 5750  new nissan great friends bought one. however, ...
# 5751  cybersol... excitement slushbox don't seem com...
# 5752  "excitement slushbox don't seem compatible."ag...
# 5753  riez, heard speed sensitive steering? varies p...
# 5754  cybersol... two types. tied engine output tied...
# 5755  yeah, brouchure don't mention difference tl tl...
# 5756  cybersol... i've read, better variable power a...
# 5757  so, read group, alot references went audi... g...
# 5758  driven both? s4 really moves. even audi's 0-60...
# 5759  i've tested 3.0, s4. hmmm... new s4 '03, huh? ...
# 5760  yeah, current s4 250 hp 258 lb-ft torque. torq...
# 5761  fast. merit "nationality based" debate. let ex...
# 5762  problem huge generalizations. also, talking ja...
# 5763  found powerful cars like g35 chevrolet differe...
# 5764  theory explain english cars? country steeped t...
# 5765  "being automatic enjoy coffee, shave, talk cel...
# 5766  mention "in rush hour traffic." like there's a...
# 5767  edmunds new feature called "true cost own". li...
# 5768  chance look person, 38k volkswagen w8 fit entr...
# 5769  it's really performance sedan. drive one take ...
# 5770  beg differ.while admit biased (obviously, sinc...
# 0     audi bmw acura nissan volkswagen honda toyota ...
#
# [5772 rows x 5 columns]

# %%
#fdist1 = FreqDist(message_without_stopwords)
#careful- don't want to count same message twice if brand is stated twice
forum_data['message_without_stopwords'].str.contains('acura').value_counts()[True] #995 contain acura
#forum_data['message_without_stopwords'].str.contains('mercedes').value_counts()[True] #597

counter={}
for brand in model_list['Replace'].drop_duplicates():
    if len(forum_data['message_without_stopwords'].str.contains(brand).value_counts().values)>1:
        count=forum_data['message_without_stopwords'].str.contains(brand).value_counts()[True]
    else:
        count=0
    counter[brand]=count
counter
# Out:
# {'acura': 996,
#  'audi': 1195,
#  'bmw': 996,
#  'buick': 199,
#  'cadillac': 0,
#  'chevrolet': 199,
#  'chrysler': 598,
#  'dodge': 0,
#  'ford': 199,
#  'honda': 797,
#  'hyundai': 199,
#  'infiniti': 398,
#  'kia': 0,
#  'lincoln': 398,
#  'mazda': 398,
#  'mercedes': 598,
#  'mercury': 0,
#  'mitsubishi': 398,
#  'nissan': 996,
#  'pontiac': 0,
#  'saturn': 0,
#  'subaru': 399,
#  'suzuki': 398,
#  'toyota': 797,
#  'volkswagen': 797,
#  'volvo': 199}

# %%
#model_list['Replace'].value_counts()
#we could change the actual file to fix mercedes-benz and mercedes benz and mercedes etc

# %%
mask=forum_data['message'].str.contains('camrybest')
forum_data[mask]
# Out:
# Empty DataFrame
# Columns: [date, userid, message, message_clean, message_without_stopwords]
# Index: []

# %%
counterlist=[]
for key, value in counter.iteritems():
    temp = [key,value]
    counterlist.append(temp)
counterlist

sorted(counterlist, key=lambda x: x[1],reverse=True)
top10=sorted(counterlist, key=lambda x: x[1],reverse=True)[:10]
top10
#need to fix mispellings in that excel
# Out:
# [['audi', 1195],
#  ['bmw', 996],
#  ['acura', 996],
#  ['nissan', 996],
#  ['volkswagen', 797],
#  ['honda', 797],
#  ['toyota', 797],
#  ['chrysler', 598],
#  ['mercedes', 598],
#  ['subaru', 399]]

# %%
#dictionary of top 10 to values and list of top 10 brands
num={}
for i in top10:
    num[i[0]]=i[1]
num

listof10=[]
for i in top10:
    listof10.append(i[0])
listof10
num
# Out:
# {'acura': 996,
#  'audi': 1195,
#  'bmw': 996,
#  'chrysler': 598,
#  'honda': 797,
#  'mercedes': 598,
#  'nissan': 996,
#  'subaru': 399,
#  'toyota': 797,
#  'volkswagen': 797}

# %%
import itertools
print list(itertools.combinations(listof10,2))
# Out:
# [('audi', 'bmw'), ('audi', 'acura'), ('audi', 'nissan'), ('audi', 'volkswagen'), ('audi', 'honda'), ('audi', 'toyota'), ('audi', 'chrysler'), ('audi', 'mercedes'), ('audi', 'subaru'), ('bmw', 'acura'), ('bmw', 'nissan'), ('bmw', 'volkswagen'), ('bmw', 'honda'), ('bmw', 'toyota'), ('bmw', 'chrysler'), ('bmw', 'mercedes'), ('bmw', 'subaru'), ('acura', 'nissan'), ('acura', 'volkswagen'), ('acura', 'honda'), ('acura', 'toyota'), ('acura', 'chrysler'), ('acura', 'mercedes'), ('acura', 'subaru'), ('nissan', 'volkswagen'), ('nissan', 'honda'), ('nissan', 'toyota'), ('nissan', 'chrysler'), ('nissan', 'mercedes'), ('nissan', 'subaru'), ('volkswagen', 'honda'), ('volkswagen', 'toyota'), ('volkswagen', 'chrysler'), ('volkswagen', 'mercedes'), ('volkswagen', 'subaru'), ('honda', 'toyota'), ('honda', 'chrysler'), ('honda', 'mercedes'), ('honda', 'subaru'), ('toyota', 'chrysler'), ('toyota', 'mercedes'), ('toyota', 'subaru'), ('chrysler', 'mercedes'), ('chrysler', 'subaru'), ('mercedes', 'subaru')]

# %%
#need how many messages each combination occurs in

# %%
#calculate lift for associations between the top 10 brands
def lift(a,b):
# Out:
#   File "<ipython-input-303-616b1786efbd>", line 3
#
#     ^
# IndentationError: expected an indented block

# %%
#final_df['message_replace']=final_df['message_without_stopwords'].apply(lambda x: ' '.join([model_list.replace for word in x.split() if word not in (model_list.Search)]))

# %% [markdown]
# #### Task B:
# What insights can you offer brand managers from your analysis in Task A    (choose two brands that you can offer the most interesting/useful insights for)?

# %% [markdown]
# #### Task C:
# What are 5   most frequently mentioned attributes of cars in the discussions? Note that the same attribute may be described by different words –   e.g., pick-up and acceleration may both referto a more general attribute, “performance”. You have to make suitable replacements. Now pick the 5 most frequently mentioned brands. Which attributes are most strongly associated with which of these 5   brands? You DON’T have to do a sentiment analysis for this assignment.
# While BMW has claimed that they are the “ultimate driving machine”, is    that how people feel on Edmunds? Show your analysis.

# %% [markdown]
# #### Task D:
# What advice will you give to a (i) product manager, and (ii) marketing/advertising manager of these brands based on your analysis in Task C? For this assignment, you can assume the sentiment (e.g., that it   is    positive).

# %% [markdown]
# #### Task E:
# Which is the most aspirational brand in your data in terms of people actually wanting to buy or own? Describe your analysis. What are the business implications for this brand? Provide the following details in your write-up (I    am not setting a   strict page limit, but 3-4 pages, single-spaced, 11 font size should be enough with screenshots)
#
# 1.Which forum you chose (provide URL)
#
# 2.Which 10 brands you chose –   provide the frequency table
#
# 3.Show all lift calculations in a   table.
#
# 4.Show the MDS map (put screenshots in your report)
#
# 5.State the 5   attributes you chose (again, a   table is    good here).
#
# 6.For task E, provide all details of your analysis –   e.g., how you measured “aspirational” and howyou found the most aspirational brand.
#
# 7.Advice/insights based on your analysis for brand, product and advertising managers. Your submission should include all scripts as well as your answers to the questions above (generally speaking, I  won’t run these scripts, but if   the numbers don’t look right, I may run some of them). Also include the final data file after all replacements of models and attributes have been done.
